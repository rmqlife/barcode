# %%
from marker import marker
import matplotlib.pyplot as plt
import cv2
frame = cv2.imread('sample/scene.jpg')
result, show_img = marker().find(frame, debug = 0, show = 1)
plt.imshow(show_img)
plt.show()

(label,pos) = result
pos = result[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-92f6f09b471c> in <module>()
#       8
#       9 label = result[0]
# ---> 10 pos = result[1]
#
# IndexError: list index out of range
